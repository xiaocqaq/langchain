# %% [markdown]
# # 1、流式调用(stream)
#
# 举例：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)
STEP_API_KEY = os.getenv("STEP_API_KEY")
STEP_BASE_URL = os.getenv("STEP_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="openai:step-3.7-flash",
    # model_provider="openai",
    api_key=STEP_API_KEY,
    base_url=STEP_BASE_URL,
)

# %%
for chunk in model.stream("帮我解释一下什么是人工智能？"):
    print(chunk.text,end="",flush=True)
# Out:
# 人工智能（Artificial Intelligence，简称AI）本质上是**人类研发的、试图模拟人类智能行为的计算系统**，你可以把它理解成「人造的类人智能」，核心目标是让机器完成原本只有人才能做的认知、推理、决策类任务。
#
# ### 先给你举个最直观的类比：
# 以前的机器都是「体力替代者」：蒸汽机代替人搬重物、汽车代替人跑路、洗衣机代替人搓衣服，解决的是体力层面的问题；而AI是「脑力替代者」，解决的是需要动脑子的认知类工作：比如识别图片里的猫、规划不堵车的路线、帮你写文案、和人对答如流，这些原本只有人能做到的事，现在机器也能做了。
#
# ---
#
# ### 它和传统编程的软件有什么区别？
# 传统软件的逻辑是「人把所有规则都写死」：比如你要做一个人脸解锁的程序，程序员得把“人脸的特征是两只眼睛、一个鼻子、一个嘴巴，位置大概在哪”这些规则一条条写进代码里，遇到光线暗、戴口罩的情况就很容易识别失败。
# 而AI的逻辑是「让机器自己从数据里找规律」：你给它喂几十万张不同角度、光线、妆容的人脸照片，告诉它哪些是机主的、哪些不是，它自己就能总结出人脸的核心特征，哪怕你戴口罩、换发型，它也能认出来，不用人一条条写规则。
#
# ---
#
# ### 现在的AI处于什么阶段？
# 目前我们能用到的所有AI都属于**弱人工智能（也叫专用AI）**，也就是只能在特定领域完成单一任务，没有通用的认知能力：
# - 下围棋的AlphaGo只会下棋，不会帮你写代码；
# - 导航的AI只会算路线，不会帮你识别图片；
# - 聊天机器人只会对话，不会帮你开车。
# 而影视作品里那种像人一样有通用智能、能跨领域解决问题、甚至拥有自我意识的「强人工智能（通用AI）」，目前还只存在于科幻阶段，并没有真正实现。
#
# ---
#
# ### AI是怎么运作的？
# 它的运行离不开三个核心要素，你可以理解成「教机器学习」的三个必要条件：
# 1. **数据**：相当于AI的「教材」，比如教AI认猫，得给它看几十万张不同品种、角度、光线下的猫的照片，还要告诉它哪些不是猫；
# 2. **算法**：相当于AI的「学习方法」，现在主流的大模型用的是模仿人脑神经元连接结构的深度学习算法，让机器能从数据里自动总结规律；
# 3. **算力**：相当于AI的「大脑处理速度」，训练一个能聊天、能画图的大模型，需要成千上万块高端计算芯片连续跑几天，没有足够的算力，AI根本「学」不会复杂的能力。
#
# ---
#
# ### 你早就天天都在用AI了：
# - 手机刷脸解锁、支付时的身份验证，是AI在识别人脸特征；
# - 刷短视频时给你推你喜欢的内容，是AI在分析你的观看习惯；
# - 拍照时的自动美颜、夜景模式，是AI在优化画面；
# - 现在流行的AI写文案、AI画图、AI生成视频，都是大模型类的AI应用；
# - 甚至你打游戏时遇到的会和你斗智斗勇的NPC，背后也藏着AI的支撑。
#
# ---
#
# ### 最后要说明一个常见误区：
# 现在的AI本质上是「基于已有数据的模式模仿工具」，它不会真的「理解」自己在做什么，也没有自主意识、情感和创造力。有时候它会「一本正经胡说八道」（也就是行业里说的「AI幻觉」），本质是它在训练数据里找到了错误的关联、然后模仿输出，所有的能力本质上都是人类设计和训练的结果，它本身不会主动产生目标、也不会真正“思考”。

# %% [markdown]
# # 2、批量调用(batch)
#
# 举例1：一次性接收所有的响应

# %%
messages = [
    "你好，你是谁？",
    "2 + 3 * 5 = ?",
    "中国首都在哪里？"
]

responses = model.batch(messages)

for response in responses:
    print(response)
# Out:
# content='你好～我是 **Step**，由 **阶跃星辰（StepFun）** 开发的智能大语言模型。  \n我能够理解和生成自然语言，也可以处理图片等多模态信息，擅长**知识问答、逻辑推理、创意写作、数学计算**等任务。  \n\n很高兴认识你！你想了解我哪方面的能力呢？' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 202, 'prompt_tokens': 16, 'total_tokens': 218, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'step-3.7-flash', 'system_fingerprint': None, 'id': '1c529733f4a7d7d7ebdd5b67c17e9f59.6493ae31a8c281539a755d5911677352', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f17f6-bbb6-7772-bdcb-84ddaf6856fe-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 202, 'total_tokens': 218, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}
# content='The expression is evaluated using the order of operations (PEMDAS/BODMAS), where multiplication is performed before addition.\n\nFirst, multiply 3 and 5:\n3 × 5 = 15\n\nThen add 2:\n2 + 15 = 17\n\nSo, 2 + 3 × 5 = 17.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 125, 'prompt_tokens': 21, 'total_tokens': 146, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'step-3.7-flash', 'system_fingerprint': None, 'id': 'de1767f1182f380cd3975ca9c83750a3.e8aaa8f679d0b2d02bbc0b1ec325e1b6', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f17f6-bbb0-71a3-89ba-af8d79ae0eb5-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 21, 'output_tokens': 125, 'total_tokens': 146, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}
# content='中华人民共和国的首都是北京。\n北京位于中国华北地区，是中国的直辖市，是全国的政治中心、文化中心、国际交往中心和科技创新中心，同时也是举世闻名的历史古都和现代化国际城市。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 239, 'prompt_tokens': 17, 'total_tokens': 256, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'step-3.7-flash', 'system_fingerprint': None, 'id': '42bf2e79cffa47d0fb8c89a00f50ba8b.fbbc28065acf0465bdc0dcb7fb952b17', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f17f6-bbe4-7620-a857-394f04cdf444-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 17, 'output_tokens': 239, 'total_tokens': 256, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}

# %% [markdown]
# 举例2：按照完成的顺序接收响应

# %%
messages = [
    "你好，你是谁？",
    "2 + 3 * 5 = ?",
    "中国首都在哪里？"
]

responses = model.batch_as_completed(messages)

for response in responses:
    print(response)
# Out:
# (1, AIMessage(content='The expression is evaluated using the order of operations (multiplication before addition):\n\n1. Multiply: \\(3 \\times 5 = 15\\)\n2. Add: \\(2 + 15 = 17\\)\n\nSo, \\(2 + 3 \\times 5 = 17\\).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 127, 'prompt_tokens': 21, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'step-3.7-flash', 'system_fingerprint': None, 'id': 'b59652a34e76f722e4ca516a12ddd7a2.54bfac73660fcec80d5c324a246e54c5', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f17f7-05e3-7d20-8256-35113232a1ea-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 21, 'output_tokens': 127, 'total_tokens': 148, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}))
# (2, AIMessage(content='中国的首都是**北京**。  \n作为中华人民共和国的首都，北京是全国的政治中心、文化中心、国际交往中心和科技创新中心。它位于中国北部，有着悠久的历史和丰富的文化遗产，例如故宫、天坛、长城（八达岭、慕田峪等）等著名景点。\n\n如果您有其他关于北京或中国的问题，欢迎随时提问！ 😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 251, 'prompt_tokens': 17, 'total_tokens': 268, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'step-3.7-flash', 'system_fingerprint': None, 'id': '3c48ef458afb49f43079af92a2d0ae3d.b5267e5e6d238b21d2aabb26a99dcad1', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f17f7-05f6-7970-9223-b4a9f9c3d358-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 251, 'total_tokens': 268, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}))
# (0, AIMessage(content='你好！我是 **Step**，由 **阶跃星辰（StepFun）** 开发的大语言模型。  \n我能够理解和生成自然语言，也可以进行多模态推理（比如分析文字和图片），帮助你解答问题、提供创意灵感、辅助学习或工作等。  \n\n如果你有任何问题或想聊什么，都可以直接告诉我～ 😊  \n你想先了解我的哪些能力呢？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 180, 'prompt_tokens': 16, 'total_tokens': 196, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'step-3.7-flash', 'system_fingerprint': None, 'id': '8eeb43437fba14fac55c2839b77fd04d.d4265aa68bfc29bbf158c45e5a91c006', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f17f7-05d7-71a1-88d2-583c2064d33f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 180, 'total_tokens': 196, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}))

# %% [markdown]
# 举例3：性能对比
#
# 使用batch

# %%
# 准备多个输入
inputs = [
    "翻译成英文：春天来了",
    "翻译成英文：夏天很热",
    "翻译成英文：秋天落叶",
    "翻译成英文：冬天下雪"
]

# ✅ 批量调用（高效）
import time

start = time.time()
responses = model.batch(inputs)
batch_time = time.time() - start

print("批量调用结果：")
for i, response in enumerate(responses):
    print(f"{i+1}. {response.content}")
print(f"耗时: {batch_time:.2f}秒\n")
# Out:
# 批量调用结果：
# 1. 最贴合原句语感的常用翻译可根据场景选择：
# 1. 最通用、直白的表述：**Spring has come.** 或 **Spring has arrived.**
#    例句：春天来了，天气渐渐变暖。→ *Spring has come, and the weather is getting warmer and warmer.*
# 2. 更口语化、有亲切感的表述：**Spring is here.**
#    这个表达会更有“春天已经来到我们身边”的生动感，日常对话里使用频率很高。
#    例句：春天来了，一起去踏青吧！→ *Spring is here! Let's go for a spring outing.*
# 3. 如果要表达“春意正浓”的引申义，还可以说 *Spring is in the air.*，意思是空气中都弥漫着春天的气息。
# 2. 最通用、符合日常表达习惯的翻译是：
# **It's very hot in summer.**
#
# 补充不同场景下的常用说法：
# 1. 若侧重描述夏天本身的普遍属性，也可以说 *Summer is very hot.*；表达“每年夏天都很热”的普遍规律时，用复数更自然：*Summers are very hot.*
# 2. 口语中想强调热度的程度，可以把very替换成really/super：*It's really hot in summer.* / *Summer is super hot.*
# 3. 特指某个地方的夏天热的话，可以加上地点，比如：*It's very hot in summer in Guangzhou.*
# 3. ### 最通用的翻译（对应名词性短语，指「秋天的落叶」这一事物）：
# **autumn leaves**
# （美式常用，英式也可用fall leaves，因为英式英语里秋天常说fall）
#
# ---
# ### 不同场景的延伸翻译：
# 1. 描述「（叶子在）秋天飘落」的动态场景/动作：
# **falling autumn leaves** / **autumn leaves falling**
# 例：Autumn leaves falling make the street very romantic. 秋天落叶飘下来让街道很有浪漫感。
#
# 2. 特指已经落在地上的秋叶：
# **fallen autumn leaves**
#
# 3. 更书面、诗意的表达，指秋天落叶的景观：
# **the falling of autumn leaves** / 也可用 **autumn foliage**（foliage指植被、树叶的总称，常用来指代秋季漫山遍野的红叶、落叶景观）
# 4. 最常用的通用翻译（陈述冬天普遍会下雪的自然现象）是：
# **It snows in winter.**
#
# 如果是描述某个特定冬天下了雪的情况，也可以根据时态调整：
# - 描述过去的某次下雪：It snowed that winter.（那年的冬天下雪了）
# - 描述将来的下雪：It will snow this winter.（今年冬天下雪了）
# 耗时: 8.60秒

# %% [markdown]
# 作为对比，演示循环调用invoke()

# %%
# ❌ 循环调用（低效，仅用于对比）
inputs = [
    "翻译成英文：春天来了",
    "翻译成英文：夏天很热",
    "翻译成英文：秋天落叶",
    "翻译成英文：冬天下雪"
]

start = time.time()
loop_responses = []
for inp in inputs:
    response = model.invoke(inp)
    loop_responses.append(response)
loop_time = time.time() - start

for i, response in enumerate(responses):
    print(f"{i+1}. {response.content}")

print(f"循环调用耗时: {loop_time:.2f}秒")

print(f"批量调用节省: {((loop_time - batch_time) / loop_time * 100):.1f}%")
# Out:
# 1. 最贴合原句语感的常用翻译可根据场景选择：
# 1. 最通用、直白的表述：**Spring has come.** 或 **Spring has arrived.**
#    例句：春天来了，天气渐渐变暖。→ *Spring has come, and the weather is getting warmer and warmer.*
# 2. 更口语化、有亲切感的表述：**Spring is here.**
#    这个表达会更有“春天已经来到我们身边”的生动感，日常对话里使用频率很高。
#    例句：春天来了，一起去踏青吧！→ *Spring is here! Let's go for a spring outing.*
# 3. 如果要表达“春意正浓”的引申义，还可以说 *Spring is in the air.*，意思是空气中都弥漫着春天的气息。
# 2. 最通用、符合日常表达习惯的翻译是：
# **It's very hot in summer.**
#
# 补充不同场景下的常用说法：
# 1. 若侧重描述夏天本身的普遍属性，也可以说 *Summer is very hot.*；表达“每年夏天都很热”的普遍规律时，用复数更自然：*Summers are very hot.*
# 2. 口语中想强调热度的程度，可以把very替换成really/super：*It's really hot in summer.* / *Summer is super hot.*
# 3. 特指某个地方的夏天热的话，可以加上地点，比如：*It's very hot in summer in Guangzhou.*
# 3. ### 最通用的翻译（对应名词性短语，指「秋天的落叶」这一事物）：
# **autumn leaves**
# （美式常用，英式也可用fall leaves，因为英式英语里秋天常说fall）
#
# ---
# ### 不同场景的延伸翻译：
# 1. 描述「（叶子在）秋天飘落」的动态场景/动作：
# **falling autumn leaves** / **autumn leaves falling**
# 例：Autumn leaves falling make the street very romantic. 秋天落叶飘下来让街道很有浪漫感。
#
# 2. 特指已经落在地上的秋叶：
# **fallen autumn leaves**
#
# 3. 更书面、诗意的表达，指秋天落叶的景观：
# **the falling of autumn leaves** / 也可用 **autumn foliage**（foliage指植被、树叶的总称，常用来指代秋季漫山遍野的红叶、落叶景观）
# 4. 最常用的通用翻译（陈述冬天普遍会下雪的自然现象）是：
# **It snows in winter.**
#
# 如果是描述某个特定冬天下了雪的情况，也可以根据时态调整：
# - 描述过去的某次下雪：It snowed that winter.（那年的冬天下雪了）
# - 描述将来的下雪：It will snow this winter.（今年冬天下雪了）
# 循环调用耗时: 22.60秒
# 批量调用节省: 61.9%
